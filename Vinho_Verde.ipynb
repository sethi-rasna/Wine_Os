# %%
# Dependencies 
import pandas as pd
import numpy as np

# %%
#1. Loading dataset
wines_df = pd.read_csv('red_white.csv')
wines_df.head(20)
# Out:
#    wine_type  winetype_numeric  fixed acidity  volatile acidity  citric acid  \
# 0        red                 1            7.4             0.700         0.00
# 1        red                 1            7.8             0.880         0.00
# 2        red                 1            7.8             0.760         0.04
# 3        red                 1           11.2             0.280         0.56
# 4        red                 1            7.4             0.700         0.00
# 5        red                 1            7.4             0.660         0.00
# 6        red                 1            7.9             0.600         0.06
# 7        red                 1            7.3             0.650         0.00
# 8        red                 1            7.8             0.580         0.02
# 9        red                 1            7.5             0.500         0.36
# 10       red                 1            6.7             0.580         0.08
# ...

# %%
#2. Info about the columns 
wines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   wine_type             2940 non-null   object
#  1   winetype_numeric      2940 non-null   int64
#  2   fixed acidity         2940 non-null   float64
#  3   volatile acidity      2940 non-null   float64
#  4   citric acid           2940 non-null   float64
#  5   residual sugar        2940 non-null   float64
#  6   chlorides             2940 non-null   float64
#  7   free sulfur dioxide   2940 non-null   float64
#  8   total sulfur dioxide  2940 non-null   float64
#  9   density               2940 non-null   float64
#  10  pH                    2940 non-null   float64
#  11  sulphates             2940 non-null   float64
#  12  alcohol               2940 non-null   float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 298.7+ KB

# %%
# if merging red and white datasets is needed in here, will do

# %%
#3. Count of RED wine instances
red_count = (wines_df["winetype_numeric"]==1).sum()

# %%
print (red_count)
# Out:
# 1470

# %%
#4. Count of WHITE wine instances
white_count = (wines_df["winetype_numeric"]==2).sum()

# %%
print (white_count)
# Out:
# 1470
